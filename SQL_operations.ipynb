# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ### 01) Write a sql query to get books that has rate >=3 and has 'Mr' in its name.

# %%
connection = sqlite3.connect('books.db')
df = pd.read_sql('''SELECT * 
                    FROM books 
                    WHERE Rate >= 3 AND Title LIKE '%Mr%' ''', connection)
df
# Out:
#     Id               Title  Price  Rate
# 0  180        Mrs. Houdini  30.25     5
# 1  282       My Mrs. Brown  24.48     3
# 2  317  Dear Mr. Knightley  11.21     5

# %% [markdown]
# ### 02) Write a sql query to get books that has rate >=3 or price > 20.

# %%
df = pd.read_sql('''SELECT * 
                    FROM books 
                    WHERE Rate >= 3 OR Price > 20''', connection)

df
# Out:
#        Id                                              Title  Price  Rate
# 0       1                               A Light in the Attic  51.77     3
# 1       2                                 Tipping the Velvet  53.74     1
# 2       3                                         Soumission  50.10     1
# 3       4                                      Sharp Objects  47.82     4
# 4       5              Sapiens: A Brief History of Humankind  54.23     5
# ..    ...                                                ...    ...   ...
# 915   996  Alice in Wonderland (Alice's Adventures in Won...  55.53     1
# 916   997   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  57.06     4
# 917   998  A Spy's Devotion (The Regency Spies of London #1)  16.97     5
# 918   999                1st to Die (Women's Murder Club #1)  53.98     1
# 919  1000                 1,000 Places to See Before You Die  26.08     5
#
# [920 rows x 4 columns]

# %% [markdown]
# ### 03) Write a sql query to get books that has rate not 3.

# %%
df = pd.read_sql('''SELECT * 
                    FROM books 
                    WHERE Rate <> 3''', connection)

df
# Out:
#        Id                                              Title  Price  Rate
# 0       2                                 Tipping the Velvet  53.74     1
# 1       3                                         Soumission  50.10     1
# 2       4                                      Sharp Objects  47.82     4
# 3       5              Sapiens: A Brief History of Humankind  54.23     5
# 4       6                                    The Requiem Red  22.65     1
# ..    ...                                                ...    ...   ...
# 792   996  Alice in Wonderland (Alice's Adventures in Won...  55.53     1
# 793   997   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  57.06     4
# 794   998  A Spy's Devotion (The Regency Spies of London #1)  16.97     5
# 795   999                1st to Die (Women's Murder Club #1)  53.98     1
# 796  1000                 1,000 Places to See Before You Die  26.08     5
#
# [797 rows x 4 columns]

# %% [markdown]
# ### 04) Write a sql query to get books that has price between 10 and 40 and has rate 3 or 4 or 1.

# %%
df = pd.read_sql('''SELECT * 
                    FROM books 
                    WHERE (Price BETWEEN 10 AND 40) AND (Rate IN(1,3,4))''', connection)
df
# Out:
#       Id                                              Title  Price  Rate
# 0      6                                    The Requiem Red  22.65     1
# 1      7  The Dirty Little Secrets of Getting Your Dream...  33.34     4
# 2      8  The Coming Woman: A Novel Based on the Life of...  17.93     3
# 3      9  The Boys in the Boat: Nine Americans and Their...  22.60     4
# 4     12                              Shakespeare's Sonnets  20.66     4
# ..   ...                                                ...    ...   ...
# 350  987  Choosing Our Religion: The Spiritual Lives of ...  28.42     4
# 351  988  Charlie and the Chocolate Factory (Charlie Buc...  22.85     3
# 352  991           Bridget Jones's Diary (Bridget Jones #1)  29.82     1
# 353  992                      Bounty (Colorado Mountain #7)  37.26     4
# 354  993               Blood Defense (Samantha Brinkman #1)  20.30     3
#
# [355 rows x 4 columns]

# %% [markdown]
# ### 05) Write a sql query to get the top 5 most expensive books (order books desc with price column and then limit the result to the first 5).

# %%
df = pd.read_sql('''SELECT * 
                    FROM books
                    ORDER BY Price DESC
                    LIMIT 5 ''', connection)

df
# Out:
#     Id                               Title  Price  Rate
# 0  649  The Perfect Play (Play by Play #1)  59.99     3
# 1  618   Last One Home (New Beginnings #1)  59.98     3
# 2  861    Civilization and Its Discontents  59.95     2
# 3  561      The Barefoot Contessa Cookbook  59.92     5
# 4  367           The Diary of a Young Girl  59.90     3

# %% [markdown]
# ### 06) Write a sql query to get the 3rd 10 books in the books table order first by rate desc and then by price asc.

# %%
df = pd.read_sql('''SELECT * 
                    FROM books
                    ORDER BY Rate DESC, Price ASC
                    LIMIT 3 ''', connection)

df
# Out:
#     Id                                              Title  Price  Rate
# 0  639                         An Abundance of Katherines  10.00     5
# 1  303                               Greek Mythic History  10.23     5
# 2  591  The Power Greens Cookbook: 140 Delicious Super...  11.05     5

# %% [markdown]
# ### 07) Write a sql query to add a new category in categories table and add 5 books to this category in books table with title, rate and price.

# %%
c = input('Enter the category of books: ')
for i in range(1,6):
    book_num = 1000+i
    t = input('Enter title of the book: ')
    p = float(input('Enter the price of the book: '))
    r = int(input('Enter the rate of the book: '))
    cursor = connection.execute('INSERT INTO books (Id,Title, Price, Rate) VALUES (?, ?, ?, ?) ',[book_num,t, p, r])
    cursor = connection.execute('INSERT INTO categories (Id, Category) VALUES (?, ?) ',[book_num, c])
connection.commit()
# Out:
# Enter the category of books: Fun
# Enter title of the book: Pyramids
# Enter the price of the book: 35.5
# Enter the rate of the book: 4
# Enter title of the book: Welcome
# Enter the price of the book: 42
# Enter the rate of the book: 5
# Enter title of the book: The Hell
# Enter the price of the book: 65
# Enter the rate of the book: 2
# Enter title of the book: Our Home
# Enter the price of the book: 15.5
# Enter the rate of the book: 4
# Enter title of the book: Hi
# Enter the price of the book: 54.5
# Enter the rate of the book: 5

# %% [markdown]
# names : Pyramids, Welcome, The Hell, Our Home, Hi

# %% [markdown]
# ## Read the data

# %%
df = pd.read_sql('''SELECT * 
                    FROM books
                     ''', connection)
df
# Out:
#         Id                                  Title  Price  Rate
# 0        1                   A Light in the Attic  51.77     3
# 1        2                     Tipping the Velvet  53.74     1
# 2        3                             Soumission  50.10     1
# 3        4                          Sharp Objects  47.82     4
# 4        5  Sapiens: A Brief History of Humankind  54.23     5
# ...    ...                                    ...    ...   ...
# 1000  1001                               Pyramids  35.50     4
# 1001  1002                                Welcome  42.00     5
# 1002  1003                               The Hell  65.00     2
# 1003  1004                               Our Home  15.50     4
# 1004  1005                                     Hi  54.50     5
#
# [1005 rows x 4 columns]

# %%
df = pd.read_sql('''SELECT * 
                    FROM categories
                     ''', connection)
df
# Out:
#         Id            Category
# 0        1              Poetry
# 1        2  Historical Fiction
# 2        3             Fiction
# 3        4             Mystery
# 4        5             History
# ...    ...                 ...
# 1000  1001                 Fun
# 1001  1002                 Fun
# 1002  1003                 Fun
# 1003  1004                 Fun
# 1004  1005                 Fun
#
# [1005 rows x 2 columns]

# %% [markdown]
# ### 08) Write a sql query to update book's rate to 3 that thier price < 20£.

# %%
cursor = connection.execute('''UPDATE books SET Rate=? WHERE Price < ? ''', [3, 20])
connection.commit()
df = pd.read_sql('''SELECT * 
                    FROM books
                     ''', connection)
df
# Out:
#         Id                                  Title  Price  Rate
# 0        1                   A Light in the Attic  51.77     3
# 1        2                     Tipping the Velvet  53.74     1
# 2        3                             Soumission  50.10     1
# 3        4                          Sharp Objects  47.82     4
# 4        5  Sapiens: A Brief History of Humankind  54.23     5
# ...    ...                                    ...    ...   ...
# 1000  1001                               Pyramids  35.50     4
# 1001  1002                                Welcome  42.00     5
# 1002  1003                               The Hell  65.00     2
# 1003  1004                               Our Home  15.50     3
# 1004  1005                                     Hi  54.50     5
#
# [1005 rows x 4 columns]

# %% [markdown]
# ### 09) Write a sql query to delete all books that have price > 50£ and has rate <= 2.

# %%
cursor = connection.cursor()
cursor.execute('''PRAGMA foreign_keys = ON''')
cursor.execute('''DELETE FROM books
                WHERE Price > ? AND Rate <= ? ''', [50,2])
connection.commit()

# %%
df = pd.read_sql('''SELECT * 
                    FROM books
                     ''', connection)
df
# Out:
#        Id                                              Title  Price  Rate
# 0       1                               A Light in the Attic  51.77     3
# 1       4                                      Sharp Objects  47.82     4
# 2       5              Sapiens: A Brief History of Humankind  54.23     5
# 3       6                                    The Requiem Red  22.65     1
# 4       7  The Dirty Little Secrets of Getting Your Dream...  33.34     4
# ..    ...                                                ...    ...   ...
# 925  1000                 1,000 Places to See Before You Die  26.08     5
# 926  1001                                           Pyramids  35.50     4
# 927  1002                                            Welcome  42.00     5
# 928  1004                                           Our Home  15.50     3
# 929  1005                                                 Hi  54.50     5
#
# [930 rows x 4 columns]

# %%
df2 = pd.read_sql('''SELECT *
                    FROM categories''', connection)
df2
# Out:
#        Id     Category
# 0       1       Poetry
# 1       4      Mystery
# 2       5      History
# 3       6  Young Adult
# 4       7     Business
# ..    ...          ...
# 925  1000       Travel
# 926  1001          Fun
# 927  1002          Fun
# 928  1004          Fun
# 929  1005          Fun
#
# [930 rows x 2 columns]

# %% [markdown]
# ### 10) Write a sql query to count the number of books that have 'Secret' in thier names and price between 10£ and 25£.

# %%
rows = connection.execute('''SELECT COUNT(*)
                             FROM books
                             WHERE (Title LIKE '%secrets%') AND (Price BETWEEN 10 AND 25) ''').fetchall()

len(rows)
# Out:
# 1

# %% [markdown]
# ### 11) Write a sql query to get the minimum & maximum price for all the books that have rate 5.

# %%
rows = connection.execute('''SELECT MAX(Price),MIN(Price)
                            FROM books
                            WHERE Rate = 5 ''').fetchall()

print("Max = ",rows[0][0])
print("Min = ",rows[0][1])
# Out:
# Max =  59.92
# Min =  20.02

# %% [markdown]
# ### 12) Write a sql query to calculate the avg price for all the books that have rate 5.

# %%
rows = connection.execute('''SELECT AVG(Price)
                            FROM books
                            WHERE Rate = 5 ''').fetchall()

round(rows[0][0],2)
# Out:
# 41.14

# %% [markdown]
# ### 13) Write a sql query to sum all book's price that have rate 2 and price between 10 and 40

# %%
rows = connection.execute('''SELECT SUM(Price)
                            FROM books
                            WHERE (Rate = 2) AND (Price BETWEEN 10 AND 40) ''').fetchall()
round(rows[0][0],2)
# Out:
# 2772.75

# %% [markdown]
# ### 14) Write a sql query to join both books & categories table into one new table containing book_name & category_name & book_rate and book_price.

# %%
cursor = connection.execute('''CREATE TABLE all_details AS
                                SELECT Title AS book_name, Price AS book_price, Rate AS book_rate, Category AS category_name
                                FROM books NATURAL JOIN categories;''')
connection.commit()

# %%
df = pd.read_sql('''SELECT *
                    FROM all_details''',connection)
df
# Out:
#                                              book_name  book_price  book_rate  \
# 0                                 A Light in the Attic       51.77          3
# 1                                        Sharp Objects       47.82          4
# 2                Sapiens: A Brief History of Humankind       54.23          5
# 3                                      The Requiem Red       22.65          1
# 4    The Dirty Little Secrets of Getting Your Dream...       33.34          4
# ..                                                 ...         ...        ...
# 925                 1,000 Places to See Before You Die       26.08          5
# 926                                           Pyramids       35.50          4
# 927                                            Welcome       42.00          5
# 928                                           Our Home       15.50          3
# 929                                                 Hi       54.50          5
#
#     category_name
# ...

# %% [markdown]
# ### 15) Write a sql query to calculate how many books  have price between 20£ and 30£.

# %%
rows = connection.execute('''SELECT COUNT(*)
                            FROM books
                            WHERE Price BETWEEN 20 AND 30 ''').fetchall()
rows[0][0]
# Out:
# 207

# %% [markdown]
# ### 16) Write a sql query to calculate how many books each category has having count > 10.

# %%
df = pd.read_sql('''SELECT Category_name,COUNT(*) AS Count
                            FROM all_details
                            GROUP BY category_name
                            HAVING COUNT() > 10''', connection)
df
# Out:
#          category_name  Count
# 0        Add a comment     60
# 1             Business     11
# 2            Childrens     28
# 3             Classics     17
# 4              Default    144
# 5              Fantasy     40
# 6              Fiction     60
# 7       Food and Drink     28
# 8   Historical Fiction     24
# 9              History     16
# 10              Horror     15
# 11               Music     11
# 12             Mystery     30
# 13          Nonfiction    104
# 14              Poetry     18
# 15             Romance     33
# 16             Science     13
# 17     Science Fiction     14
# 18      Sequential Art     70
# 19            Thriller     11
# 20              Travel     11
# 21      Womens Fiction     16
# 22         Young Adult     50

# %% [markdown]
# ### 17) Write a sql query to get all books with category_name='Music' using subquery.

# %%
df = pd.read_sql('''SELECT *
                    FROM all_details
                    WHERE category_name = (SELECT Category FROM categories WHERE Category = "Music" )''',connection)
df
# Out:
#                                             book_name  book_price  book_rate  \
# 0                           Rip it Up and Start Again       35.02          5
# 1   Our Band Could Be Your Life: Scenes from the A...       57.25          3
# 2                                     How Music Works       37.32          2
# 3                       Love Is a Mix Tape (Music #1)       18.03          3
# 4   Please Kill Me: The Uncensored Oral History of...       31.19          4
# 5   Kill 'Em and Leave: Searching for James Brown ...       45.05          5
# 6   This Is Your Brain on Music: The Science of a ...       38.40          1
# 7   Orchestra of Exiles: The Story of Bronislaw Hu...       12.36          3
# 8                          No One Here Gets Out Alive       20.02          5
# 9                                                Life       31.58          5
# 10                   Forever Rockers (The Rocker #12)       28.80          3
#
#    category_name
# 0          Music
# ...

# %%
df = pd.read_sql('''SELECT * FROM all_details''',connection)
df
# Out:
#                                              book_name  book_price  book_rate  \
# 0                                 A Light in the Attic       51.77          3
# 1                                        Sharp Objects       47.82          4
# 2                Sapiens: A Brief History of Humankind       54.23          5
# 3                                      The Requiem Red       22.65          1
# 4    The Dirty Little Secrets of Getting Your Dream...       33.34          4
# ..                                                 ...         ...        ...
# 925                 1,000 Places to See Before You Die       26.08          5
# 926                                           Pyramids       35.50          4
# 927                                            Welcome       42.00          5
# 928                                           Our Home       15.50          3
# 929                                                 Hi       54.50          5
#
#     category_name
# ...

# %%
connection.close()

# %%
df.to_csv("books.csv",index=False)

# %%
df = pd.read_csv('books.csv')
df
# Out:
#                                              book_name  book_price  book_rate  \
# 0                                 A Light in the Attic       51.77          3
# 1                                        Sharp Objects       47.82          4
# 2                Sapiens: A Brief History of Humankind       54.23          5
# 3                                      The Requiem Red       22.65          1
# 4    The Dirty Little Secrets of Getting Your Dream...       33.34          4
# ..                                                 ...         ...        ...
# 925                 1,000 Places to See Before You Die       26.08          5
# 926                                           Pyramids       35.50          4
# 927                                            Welcome       42.00          5
# 928                                           Our Home       15.50          3
# 929                                                 Hi       54.50          5
#
#     category_name
# ...
